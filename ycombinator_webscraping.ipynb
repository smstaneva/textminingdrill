# %%
#Import common modules

# %%
import numpy as np

# %%
from urllib import request

# %%
from bs4 import BeautifulSoup

# %%
webpage = request.urlopen("https://news.ycombinator.com").read()

# %%
page = BeautifulSoup(webpage, 'html.parser')

# %%
page
# Out:
# <html op="news"><head><meta content="origin" name="referrer"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/><link href="news.css?vb3r9NyQJtwe3LZVnQKu" rel="stylesheet" type="text/css"/>
# <link href="favicon.ico" rel="shortcut icon"/>
# <link href="rss" rel="alternate" title="RSS" type="application/rss+xml"/>
# <title>Hacker News</title></head><body><center><table bgcolor="#f6f6ef" border="0" cellpadding="0" cellspacing="0" id="hnmain" width="85%">
# <tr><td bgcolor="#ff6600"><table border="0" cellpadding="0" cellspacing="0" style="padding:2px" width="100%"><tr><td style="width:18px;padding-right:4px"><a href="https://news.ycombinator.com"><img height="18" src="y18.gif" style="border:1px white solid;" width="18"/></a></td>
# <td style="line-height:12pt; height:10px;"><span class="pagetop"><b class="hnname"><a href="news">Hacker News</a></b>
# ...

# %%
type(page)
# Out:
# bs4.BeautifulSoup

# %%
print(page.prettify())
# Out:
# <html op="news">
#  <head>
#   <meta content="origin" name="referrer"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="news.css?vb3r9NyQJtwe3LZVnQKu" rel="stylesheet" type="text/css"/>
#   <link href="favicon.ico" rel="shortcut icon"/>
#   <link href="rss" rel="alternate" title="RSS" type="application/rss+xml"/>
#   <title>
#    Hacker News
#   </title>
#  </head>
#  <body>
#   <center>
#    <table bgcolor="#f6f6ef" border="0" cellpadding="0" cellspacing="0" id="hnmain" width="85%">
#     <tr>
#      <td bgcolor="#ff6600">
#       <table border="0" cellpadding="0" cellspacing="0" style="padding:2px" width="100%">
#        <tr>
#         <td style="width:18px;padding-right:4px">
#          <a href="https://news.ycombinator.com">
#           <img height="18" src="y18.gif" style="border:1px white solid;" width="18"/>
#          </a>
#         </td>
#         <td style="line-height:12pt; height:10px;">
#          <span class="pagetop">
# ...

# %%
#Find all requred elements within the page

# %%
for i in page.find_all('a', {"class":"storylink"}, href=True):
    for y in page.find_all('a', {"class":"hnuser"}, href=True):
        for z in page.find_all('span', {"class":"score"}):
            for w in page.find_all('span', {"class":"rank"}):
                data = 'Title: '+i.text+', \n''Url: '+i.attrs['href']+', \n''Author: '+y.text+', \n''Points: '+z.text+', \n''Rank: '+w.text
                print(data)
# Out:
# Title: LinkedIn loses appeal over access to user profiles,
# Url: https://www.reuters.com/article/us-microsoft-linkedin-profiles/microsofts-linkedin-loses-appeal-over-access-to-user-profiles-idUSKCN1VU21W,
# Author: isalmon,
# Points: 313 pointsRank: 1.
# Title: LinkedIn loses appeal over access to user profiles,
# Url: https://www.reuters.com/article/us-microsoft-linkedin-profiles/microsofts-linkedin-loses-appeal-over-access-to-user-profiles-idUSKCN1VU21W,
# Author: isalmon,
# Points: 313 pointsRank: 2.
# Title: LinkedIn loses appeal over access to user profiles,
# Url: https://www.reuters.com/article/us-microsoft-linkedin-profiles/microsofts-linkedin-loses-appeal-over-access-to-user-profiles-idUSKCN1VU21W,
# Author: isalmon,
# Points: 313 pointsRank: 3.
# Title: LinkedIn loses appeal over access to user profiles,
# Url: https://www.reuters.com/article/us-microsoft-linkedin-profiles/microsofts-linkedin-loses-appeal-over-access-to-user-profiles-idUSKCN1VU21W,
# Author: isalmon,
# ...
